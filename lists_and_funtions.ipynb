# %%
# 7.4, 7.5, 7.6, 7.7
things = ["MOZZARELLA", "Cinderella"]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
#9.1
def good():
    return ['Harry', 'ron', 'Hermone']

good()
# Out:
# ['Harry', 'ron', 'Hermone']

# %%
#9.2
def get_odds():
    for number in range(10):
        if number % 2:
            print(number)
        
get_odds()
# Out:
# 1
# 3
# 5
# 7
# 9
